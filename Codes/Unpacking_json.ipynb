# %%
# Dependencies
import json
import os
import pandas as pd

# %%
# Load JSON

part1= ['NCTId' , 'AgreementOtherDetails' , 'AgreementPISponsorEmployee' , 'AgreementRestrictionType' , 'AgreementRestrictiveAgreement' , 'ArmGroupDescription' , 'ArmGroupInterventionName' , 'ArmGroupLabel' , 'ArmGroupType' , 'AvailIPDComment' , 'AvailIPDId' , 'AvailIPDType' , 'AvailIPDURL' , 'BaselineCategoryTitle' , 'BaselineClassDenomCountGroupId' , 'BaselineClassDenomCountValue' , 'BaselineClassDenomUnits' , 'BaselineClassTitle' , 'BaselineDenomCountGroupId' , 'BaselineDenomCountValue']


# with open('json2/field_usa0_part_1.json') as jsonfile:
#     study_json = json.load(jsonfile)

# %%
#Joining USA0 and USA1

# all fields of part 1
NCTId=[]
AgreementOtherDetails = []
AgreementPISponsorEmployee = []
AgreementRestrictionType = []
AgreementRestrictiveAgreement = []
ArmGroupDescription = []
ArmGroupInterventionName = []
ArmGroupLabel = []
ArmGroupType = []
AvailIPDComment = []
AvailIPDId = []
AvailIPDType = []
AvailIPDURL = []
BaselineCategoryTitle = []
BaselineClassDenomCountGroupId = []
BaselineClassDenomCountValue = []
BaselineClassDenomUnits = []
BaselineClassTitle = []
BaselineDenomCountGroupId = []
BaselineDenomCountValue = []

# %%
#Extract All of Part1

rank_number = len(study_json["StudyFieldsResponse"]["StudyFields"])
fields_number =len( study_json["StudyFieldsResponse"]["StudyFields"][0])
print (rank_number)

#Extracting from multiple files

for trial_batch in range (0,2):

    trial_batch = 0
    trial_path="json2/field_usa"+str(trial_batch)+"_part_1.json"

    with open(trial_path) as jsonfile:
        study_json = json.load(jsonfile)

    rank_number = len(study_json["StudyFieldsResponse"]["StudyFields"])
    fields_number =len( study_json["StudyFieldsResponse"]["StudyFields"][0])

    for x in range (0,rank_number):

    #     if AgreementOtherDetails.append(study_json['StudyFieldsResponse']['StudyFields'][x]['AgreementOtherDetails']='':
    #         AgreementOtherDetails.append(0)
    #     else:
    #         AgreementOtherDetails.append(study_json['StudyFieldsResponse']['StudyFields'][x]['AgreementOtherDetails'][0]

        study_content= study_json['StudyFieldsResponse']['StudyFields'][x]

        if len(study_content['NCTId']) ==0 :
            NCTId.append(0)
        if len(study_content['NCTId']) ==1 :
            NCTId.append(study_content['NCTId'][0]) 
        elif len(study_content['NCTId']) > 1:
            NCTId.append(study_content['NCTId'])  
        if len(study_content['AgreementOtherDetails']) ==0 :
            AgreementOtherDetails.append(0)
        if len(study_content['AgreementOtherDetails']) ==1 :
            AgreementOtherDetails.append(study_content['AgreementOtherDetails'][0]) 
        elif len(study_content['AgreementOtherDetails']) > 1:
            AgreementOtherDetails.append(study_content['AgreementOtherDetails'])  
        if len(study_content['AgreementPISponsorEmployee']) ==0 :
            AgreementPISponsorEmployee.append(0)
        if len(study_content['AgreementPISponsorEmployee']) ==1 :
            AgreementPISponsorEmployee.append(study_content['AgreementPISponsorEmployee'][0]) 
        elif len(study_content['AgreementPISponsorEmployee']) > 1:
            AgreementPISponsorEmployee.append(study_content['AgreementPISponsorEmployee'])  
        if len(study_content['AgreementRestrictionType']) ==0 :
            AgreementRestrictionType.append(0)
        if len(study_content['AgreementRestrictionType']) ==1 :
            AgreementRestrictionType.append(study_content['AgreementRestrictionType'][0]) 
        elif len(study_content['AgreementRestrictionType']) > 1:
            AgreementRestrictionType.append(study_content['AgreementRestrictionType'])  
        if len(study_content['AgreementRestrictiveAgreement']) ==0 :
            AgreementRestrictiveAgreement.append(0)
        if len(study_content['AgreementRestrictiveAgreement']) ==1 :
            AgreementRestrictiveAgreement.append(study_content['AgreementRestrictiveAgreement'][0]) 
        elif len(study_content['AgreementRestrictiveAgreement']) > 1:
            AgreementRestrictiveAgreement.append(study_content['AgreementRestrictiveAgreement'])  
        if len(study_content['ArmGroupDescription']) ==0 :
            ArmGroupDescription.append(0)
        if len(study_content['ArmGroupDescription']) ==1 :
            ArmGroupDescription.append(study_content['ArmGroupDescription'][0]) 
        elif len(study_content['ArmGroupDescription']) > 1:
            ArmGroupDescription.append(study_content['ArmGroupDescription'])  
        if len(study_content['ArmGroupInterventionName']) ==0 :
            ArmGroupInterventionName.append(0)
        if len(study_content['ArmGroupInterventionName']) ==1 :
            ArmGroupInterventionName.append(study_content['ArmGroupInterventionName'][0]) 
        elif len(study_content['ArmGroupInterventionName']) > 1:
            ArmGroupInterventionName.append(study_content['ArmGroupInterventionName'])  
        if len(study_content['ArmGroupLabel']) ==0 :
            ArmGroupLabel.append(0)
        if len(study_content['ArmGroupLabel']) ==1 :
            ArmGroupLabel.append(study_content['ArmGroupLabel'][0]) 
        elif len(study_content['ArmGroupLabel']) > 1:
            ArmGroupLabel.append(study_content['ArmGroupLabel'])  
        if len(study_content['ArmGroupType']) ==0 :
            ArmGroupType.append(0)
        if len(study_content['ArmGroupType']) ==1 :
            ArmGroupType.append(study_content['ArmGroupType'][0]) 
        elif len(study_content['ArmGroupType']) > 1:
            ArmGroupType.append(study_content['ArmGroupType'])  
        if len(study_content['AvailIPDComment']) ==0 :
            AvailIPDComment.append(0)
        if len(study_content['AvailIPDComment']) ==1 :
            AvailIPDComment.append(study_content['AvailIPDComment'][0]) 
        elif len(study_content['AvailIPDComment']) > 1:
            AvailIPDComment.append(study_content['AvailIPDComment'])  
        if len(study_content['AvailIPDId']) ==0 :
            AvailIPDId.append(0)
        if len(study_content['AvailIPDId']) ==1 :
            AvailIPDId.append(study_content['AvailIPDId'][0]) 
        elif len(study_content['AvailIPDId']) > 1:
            AvailIPDId.append(study_content['AvailIPDId'])  
        if len(study_content['AvailIPDType']) ==0 :
            AvailIPDType.append(0)
        if len(study_content['AvailIPDType']) ==1 :
            AvailIPDType.append(study_content['AvailIPDType'][0]) 
        elif len(study_content['AvailIPDType']) > 1:
            AvailIPDType.append(study_content['AvailIPDType'])  
        if len(study_content['AvailIPDURL']) ==0 :
            AvailIPDURL.append(0)
        if len(study_content['AvailIPDURL']) ==1 :
            AvailIPDURL.append(study_content['AvailIPDURL'][0]) 
        elif len(study_content['AvailIPDURL']) > 1:
            AvailIPDURL.append(study_content['AvailIPDURL'])  
        if len(study_content['BaselineCategoryTitle']) ==0 :
            BaselineCategoryTitle.append(0)
        if len(study_content['BaselineCategoryTitle']) ==1 :
            BaselineCategoryTitle.append(study_content['BaselineCategoryTitle'][0]) 
        elif len(study_content['BaselineCategoryTitle']) > 1:
            BaselineCategoryTitle.append(study_content['BaselineCategoryTitle'])  
        if len(study_content['BaselineClassDenomCountGroupId']) ==0 :
            BaselineClassDenomCountGroupId.append(0)
        if len(study_content['BaselineClassDenomCountGroupId']) ==1 :
            BaselineClassDenomCountGroupId.append(study_content['BaselineClassDenomCountGroupId'][0]) 
        elif len(study_content['BaselineClassDenomCountGroupId']) > 1:
            BaselineClassDenomCountGroupId.append(study_content['BaselineClassDenomCountGroupId'])  
        if len(study_content['BaselineClassDenomCountValue']) ==0 :
            BaselineClassDenomCountValue.append(0)
        if len(study_content['BaselineClassDenomCountValue']) ==1 :
            BaselineClassDenomCountValue.append(study_content['BaselineClassDenomCountValue'][0]) 
        elif len(study_content['BaselineClassDenomCountValue']) > 1:
            BaselineClassDenomCountValue.append(study_content['BaselineClassDenomCountValue'])  
        if len(study_content['BaselineClassDenomUnits']) ==0 :
            BaselineClassDenomUnits.append(0)
        if len(study_content['BaselineClassDenomUnits']) ==1 :
            BaselineClassDenomUnits.append(study_content['BaselineClassDenomUnits'][0]) 
        elif len(study_content['BaselineClassDenomUnits']) > 1:
            BaselineClassDenomUnits.append(study_content['BaselineClassDenomUnits'])  
        if len(study_content['BaselineClassTitle']) ==0 :
            BaselineClassTitle.append(0)
        if len(study_content['BaselineClassTitle']) ==1 :
            BaselineClassTitle.append(study_content['BaselineClassTitle'][0]) 
        elif len(study_content['BaselineClassTitle']) > 1:
            BaselineClassTitle.append(study_content['BaselineClassTitle'])  
        if len(study_content['BaselineDenomCountGroupId']) ==0 :
            BaselineDenomCountGroupId.append(0)
        if len(study_content['BaselineDenomCountGroupId']) ==1 :
            BaselineDenomCountGroupId.append(study_content['BaselineDenomCountGroupId'][0]) 
        elif len(study_content['BaselineDenomCountGroupId']) > 1:
            BaselineDenomCountGroupId.append(study_content['BaselineDenomCountGroupId'])  
        if len(study_content['BaselineDenomCountValue']) ==0 :
            BaselineDenomCountValue.append(0)
        if len(study_content['BaselineDenomCountValue']) ==1 :
            BaselineDenomCountValue.append(study_content['BaselineDenomCountValue'][0]) 
        elif len(study_content['BaselineDenomCountValue']) > 1:
            BaselineDenomCountValue.append(study_content['BaselineDenomCountValue'])  






    

                                     
#     try:
#         AgreementOtherDetails.append(study_json['StudyFieldsResponse']['StudyFields'][x]['AgreementOtherDetails'][0])
#         print (AgreementOtherDetails)
#     except:
#         AgreementOtherDetails.append(0)
#     print (AgreementOtherDetails)
# study_json["StudyFieldsResponse"]["StudyFields"][0]['ArmGroupDescription'][0]


        

# for x in range ();
# Out:
# 1000

# %% [markdown]
# with open('json2/field_usa0_part_1.json') as jsonfile:
#     study_json = json.load(jsonfile)
#
# # Extracting all of AgreementOtherDetails
# rank_number = len(study_json["StudyFieldsResponse"]["StudyFields"])
# fields_number =len( study_json["StudyFieldsResponse"]["StudyFields"][0])
# print (rank_number)
# #real data starts at 2
#
# for x in range (0,rank_number):
#
# #     if AgreementOtherDetails.append(study_json['StudyFieldsResponse']['StudyFields'][x]['AgreementOtherDetails']='':
# #         AgreementOtherDetails.append(0)
# #     else:
# #         AgreementOtherDetails.append(study_json['StudyFieldsResponse']['StudyFields'][x]['AgreementOtherDetails'][0]
#
#     study_content= study_json['StudyFieldsResponse']['StudyFields'][x]
#
#     if len(study_content['NCTId']) ==0 :
#         NCTId.append(0)
#     if len(study_content['NCTId']) ==1 :
#         NCTId.append(study_content['NCTId'][0])
#     elif len(study_content['NCTId']) > 1:
#         NCTId.append(study_content['NCTId'])
#     if len(study_content['AgreementOtherDetails']) ==0 :
#         AgreementOtherDetails.append(0)
#     if len(study_content['AgreementOtherDetails']) ==1 :
#         AgreementOtherDetails.append(study_content['AgreementOtherDetails'][0])
#     elif len(study_content['AgreementOtherDetails']) > 1:
#         AgreementOtherDetails.append(study_content['AgreementOtherDetails'])
#     if len(study_content['AgreementPISponsorEmployee']) ==0 :
#         AgreementPISponsorEmployee.append(0)
#     if len(study_content['AgreementPISponsorEmployee']) ==1 :
#         AgreementPISponsorEmployee.append(study_content['AgreementPISponsorEmployee'][0])
#     elif len(study_content['AgreementPISponsorEmployee']) > 1:
#         AgreementPISponsorEmployee.append(study_content['AgreementPISponsorEmployee'])
#     if len(study_content['AgreementRestrictionType']) ==0 :
#         AgreementRestrictionType.append(0)
#     if len(study_content['AgreementRestrictionType']) ==1 :
#         AgreementRestrictionType.append(study_content['AgreementRestrictionType'][0])
#     elif len(study_content['AgreementRestrictionType']) > 1:
#         AgreementRestrictionType.append(study_content['AgreementRestrictionType'])
#     if len(study_content['AgreementRestrictiveAgreement']) ==0 :
#         AgreementRestrictiveAgreement.append(0)
#     if len(study_content['AgreementRestrictiveAgreement']) ==1 :
#         AgreementRestrictiveAgreement.append(study_content['AgreementRestrictiveAgreement'][0])
#     elif len(study_content['AgreementRestrictiveAgreement']) > 1:
#         AgreementRestrictiveAgreement.append(study_content['AgreementRestrictiveAgreement'])
#     if len(study_content['ArmGroupDescription']) ==0 :
#         ArmGroupDescription.append(0)
#     if len(study_content['ArmGroupDescription']) ==1 :
#         ArmGroupDescription.append(study_content['ArmGroupDescription'][0])
#     elif len(study_content['ArmGroupDescription']) > 1:
#         ArmGroupDescription.append(study_content['ArmGroupDescription'])
#     if len(study_content['ArmGroupInterventionName']) ==0 :
#         ArmGroupInterventionName.append(0)
#     if len(study_content['ArmGroupInterventionName']) ==1 :
#         ArmGroupInterventionName.append(study_content['ArmGroupInterventionName'][0])
#     elif len(study_content['ArmGroupInterventionName']) > 1:
#         ArmGroupInterventionName.append(study_content['ArmGroupInterventionName'])
#     if len(study_content['ArmGroupLabel']) ==0 :
#         ArmGroupLabel.append(0)
#     if len(study_content['ArmGroupLabel']) ==1 :
#         ArmGroupLabel.append(study_content['ArmGroupLabel'][0])
#     elif len(study_content['ArmGroupLabel']) > 1:
#         ArmGroupLabel.append(study_content['ArmGroupLabel'])
#     if len(study_content['ArmGroupType']) ==0 :
#         ArmGroupType.append(0)
#     if len(study_content['ArmGroupType']) ==1 :
#         ArmGroupType.append(study_content['ArmGroupType'][0])
#     elif len(study_content['ArmGroupType']) > 1:
#         ArmGroupType.append(study_content['ArmGroupType'])
#     if len(study_content['AvailIPDComment']) ==0 :
#         AvailIPDComment.append(0)
#     if len(study_content['AvailIPDComment']) ==1 :
#         AvailIPDComment.append(study_content['AvailIPDComment'][0])
#     elif len(study_content['AvailIPDComment']) > 1:
#         AvailIPDComment.append(study_content['AvailIPDComment'])
#     if len(study_content['AvailIPDId']) ==0 :
#         AvailIPDId.append(0)
#     if len(study_content['AvailIPDId']) ==1 :
#         AvailIPDId.append(study_content['AvailIPDId'][0])
#     elif len(study_content['AvailIPDId']) > 1:
#         AvailIPDId.append(study_content['AvailIPDId'])
#     if len(study_content['AvailIPDType']) ==0 :
#         AvailIPDType.append(0)
#     if len(study_content['AvailIPDType']) ==1 :
#         AvailIPDType.append(study_content['AvailIPDType'][0])
#     elif len(study_content['AvailIPDType']) > 1:
#         AvailIPDType.append(study_content['AvailIPDType'])
#     if len(study_content['AvailIPDURL']) ==0 :
#         AvailIPDURL.append(0)
#     if len(study_content['AvailIPDURL']) ==1 :
#         AvailIPDURL.append(study_content['AvailIPDURL'][0])
#     elif len(study_content['AvailIPDURL']) > 1:
#         AvailIPDURL.append(study_content['AvailIPDURL'])
#     if len(study_content['BaselineCategoryTitle']) ==0 :
#         BaselineCategoryTitle.append(0)
#     if len(study_content['BaselineCategoryTitle']) ==1 :
#         BaselineCategoryTitle.append(study_content['BaselineCategoryTitle'][0])
#     elif len(study_content['BaselineCategoryTitle']) > 1:
#         BaselineCategoryTitle.append(study_content['BaselineCategoryTitle'])
#     if len(study_content['BaselineClassDenomCountGroupId']) ==0 :
#         BaselineClassDenomCountGroupId.append(0)
#     if len(study_content['BaselineClassDenomCountGroupId']) ==1 :
#         BaselineClassDenomCountGroupId.append(study_content['BaselineClassDenomCountGroupId'][0])
#     elif len(study_content['BaselineClassDenomCountGroupId']) > 1:
#         BaselineClassDenomCountGroupId.append(study_content['BaselineClassDenomCountGroupId'])
#     if len(study_content['BaselineClassDenomCountValue']) ==0 :
#         BaselineClassDenomCountValue.append(0)
#     if len(study_content['BaselineClassDenomCountValue']) ==1 :
#         BaselineClassDenomCountValue.append(study_content['BaselineClassDenomCountValue'][0])
#     elif len(study_content['BaselineClassDenomCountValue']) > 1:
#         BaselineClassDenomCountValue.append(study_content['BaselineClassDenomCountValue'])
#     if len(study_content['BaselineClassDenomUnits']) ==0 :
#         BaselineClassDenomUnits.append(0)
#     if len(study_content['BaselineClassDenomUnits']) ==1 :
#         BaselineClassDenomUnits.append(study_content['BaselineClassDenomUnits'][0])
#     elif len(study_content['BaselineClassDenomUnits']) > 1:
#         BaselineClassDenomUnits.append(study_content['BaselineClassDenomUnits'])
#     if len(study_content['BaselineClassTitle']) ==0 :
#         BaselineClassTitle.append(0)
#     if len(study_content['BaselineClassTitle']) ==1 :
#         BaselineClassTitle.append(study_content['BaselineClassTitle'][0])
#     elif len(study_content['BaselineClassTitle']) > 1:
#         BaselineClassTitle.append(study_content['BaselineClassTitle'])
#     if len(study_content['BaselineDenomCountGroupId']) ==0 :
#         BaselineDenomCountGroupId.append(0)
#     if len(study_content['BaselineDenomCountGroupId']) ==1 :
#         BaselineDenomCountGroupId.append(study_content['BaselineDenomCountGroupId'][0])
#     elif len(study_content['BaselineDenomCountGroupId']) > 1:
#         BaselineDenomCountGroupId.append(study_content['BaselineDenomCountGroupId'])
#     if len(study_content['BaselineDenomCountValue']) ==0 :
#         BaselineDenomCountValue.append(0)
#     if len(study_content['BaselineDenomCountValue']) ==1 :
#         BaselineDenomCountValue.append(study_content['BaselineDenomCountValue'][0])
#     elif len(study_content['BaselineDenomCountValue']) > 1:
#         BaselineDenomCountValue.append(study_content['BaselineDenomCountValue'])
#
#
#
#
#
#
#
#
#
# #     try:
# #         AgreementOtherDetails.append(study_json['StudyFieldsResponse']['StudyFields'][x]['AgreementOtherDetails'][0])
# #         print (AgreementOtherDetails)
# #     except:
# #         AgreementOtherDetails.append(0)
# #     print (AgreementOtherDetails)
# # study_json["StudyFieldsResponse"]["StudyFields"][0]['ArmGroupDescription'][0]
#
#
#
#
# # for x in range ();

# %%
len(BaselineDenomCountValue)
# Out:
# 2000

# %%
#Create Dataframe from list
dict1 = { part1[0]:NCTId,
part1[1]:AgreementOtherDetails,
part1[2]:AgreementPISponsorEmployee,
part1[3]:AgreementRestrictionType,
part1[4]:AgreementRestrictiveAgreement,
part1[5]:ArmGroupDescription,
part1[6]:ArmGroupInterventionName,
part1[7]:ArmGroupLabel,
part1[8]:ArmGroupType,
part1[9]:AvailIPDComment,
part1[10]:AvailIPDId,
part1[11]:AvailIPDType,
part1[12]:AvailIPDURL,
part1[13]:BaselineCategoryTitle,
part1[14]:BaselineClassDenomCountGroupId,
part1[15]:BaselineClassDenomCountValue,
part1[16]:BaselineClassDenomUnits,
part1[17]:BaselineClassTitle,
part1[18]:BaselineDenomCountGroupId,
part1[19]:BaselineDenomCountValue}

df1 = pd.DataFrame(dict1)

df1
df1.to_csv('fields_all_part1.csv')

# %%
len(study_json['StudyFieldsResponse']['StudyFields'][x]['AgreementOtherDetails'])
# Out:
# 0

# %%
len(study_json["StudyFieldsResponse"]["StudyFields"][9]['ArmGroupInterventionName'])
# Out:
# 4

# %%
df = pd.DataFrame(data)
df.tail(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-160-6396e3b6cf6b> in <module>
# ----> 1 df = pd.DataFrame(data)
#       2 df.tail(2)
#
# NameError: name 'data' is not defined

# %%
MeshID_stuffs = [[1,2,3],[4,5,6]]
Intervention_ID_stuffs = [[a,b,c],[d,e,f]]

all_iDs= [1,2,3,a,b,c]

# %%
#create index table
index_table = norm_df[['ProtocolSection.IdentificationModule.NCTId']].copy()
index_table = index_table.rename(columns={'ProtocolSection.IdentificationModule.NCTId':'NCTId'})
index_table
# Out:
#           NCTId
# 0   NCT04371159
# 1   NCT04474496
# 2   NCT02801266
# 3   NCT01599390
# 4   NCT00312702
# ..          ...
# 95  NCT02207569
# 96  NCT02569632
# 97  NCT02069925
# 98  NCT03433131
# 99  NCT02746809
#
# [100 rows x 1 columns]

# %%
kf = norm_df[['DerivedSection.ConditionBrowseModule.ConditionMeshList.ConditionMesh']]
kf= kf.fillna(0)
kf
# Out:
#    DerivedSection.ConditionBrowseModule.ConditionMeshList.ConditionMesh
# 0   [{'ConditionMeshId': 'D000014552', 'ConditionM...
# 1                                                   0
# 2                                                   0
# 3   [{'ConditionMeshId': 'D000007251', 'ConditionM...
# 4   [{'ConditionMeshId': 'D000008288', 'ConditionM...
# ..                                                ...
# 95  [{'ConditionMeshId': 'D000001024', 'ConditionM...
# 96  [{'ConditionMeshId': 'D000008589', 'ConditionM...
# 97  [{'ConditionMeshId': 'D000012559', 'ConditionM...
# 98  [{'ConditionMeshId': 'D000009290', 'ConditionM...
# 99  [{'ConditionMeshId': 'D000001024', 'ConditionM...
#
# [100 rows x 1 columns]

# %%
kiki = study_json['FullStudiesResponse']['FullStudies'][0]['Study']['DerivedSection']['ConditionBrowseModule']['ConditionMeshList']['ConditionMesh']
kiki
# Out:
# [{'ConditionMeshId': 'D000014552',
#   'ConditionMeshTerm': 'Urinary Tract Infections'}]

# %%
# normalize 'Study' section to retrieve data.
vivi1 = pd.json_normalize(study_json['FullStudiesResponse']['FullStudies'][0]['Study']['DerivedSection']['ConditionBrowseModule']['ConditionMeshList']['ConditionMesh']) 
vivi1
# Out:
#   ConditionMeshId         ConditionMeshTerm
# 0      D000014552  Urinary Tract Infections

# %%
pd.json_normalize(study_json['FullStudiesResponse']['FullStudies'][1]['Study']['DerivedSection']['ConditionBrowseModule']['ConditionMeshList']['ConditionMesh'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-c7c960fb0eea> in <module>
# ----> 1 pd.json_normalize(study_json['FullStudiesResponse']['FullStudies'][1]['Study']['DerivedSection']['ConditionBrowseModule']['ConditionMeshList']['ConditionMesh'])
#
# KeyError: 'ConditionMeshList'

# %%
for i in range (0,100):
    xixi = pd.json_normalize(study_json['FullStudiesResponse']['FullStudies'][i]['Study']['DerivedSection']['ConditionBrowseModule'])

# %%
xixi

# %%
cf = norm_df[['ProtocolSection.IdentificationModule.NCTId', 'ProtocolSection.ArmsInterventionsModule.InterventionList.Intervention']].copy()
cf = cf.rename(columns={'ProtocolSection.IdentificationModule.NCTId':'NCTId','ProtocolSection.ArmsInterventionsModule.InterventionList.Intervention': "C"})
cf = cf.fillna(0)
cf = cf.head(10)
cf
# Out:
#          NCTId                                                  C
# 0  NCT04371159  [{'InterventionType': 'Device', 'InterventionN...
# 1  NCT04474496  [{'InterventionType': 'Other', 'InterventionNa...
# 2  NCT02801266  [{'InterventionType': 'Behavioral', 'Intervent...
# 3  NCT01599390  [{'InterventionType': 'Other', 'InterventionNa...
# 4  NCT00312702  [{'InterventionType': 'Biological', 'Intervent...
# 5  NCT00312663  [{'InterventionType': 'Biological', 'Intervent...
# 6  NCT01153880  [{'InterventionType': 'Drug', 'InterventionNam...
# 7  NCT02019732  [{'InterventionType': 'Other', 'InterventionNa...
# 8  NCT03972358  [{'InterventionType': 'Drug', 'InterventionNam...
# 9  NCT00948233  [{'InterventionType': 'Behavioral', 'Intervent...

# %%
pd.DataFrame(cf['C'][1][0])
# Out:
#                           InterventionType             InterventionName  \
# InterventionArmGroupLabel            Other  Assessing impact of COVID19
#
#                                                      InterventionDescription  \
# InterventionArmGroupLabel  Surveying Marshallese adults in the U.S. to de...
#
#                           InterventionArmGroupLabelList
# InterventionArmGroupLabel     [Marshallese in the U.S.]

# %%
# eben I am able to open the list, but not to add the NCTid column. Can you help figuring this up ?

# %%
 df1 = pd.DataFrame()
 for i in range(cf.shape[0]):
     try:
        df1 = df1.append(pd.DataFrame([cf['C'][i][0]]), ignore_index = True)

     except:
        print(i)
 df1
# Out:
#   InterventionType                                   InterventionName  \
# 0           Device                                       Velieve U.S.
# 1            Other                        Assessing impact of COVID19
# 2       Behavioral         Evidence informed birth control counseling
# 3            Other                                    Data collection
# 4       Biological  Falciparum Malaria Protein 11 with AS02A adjuvant
# 5       Biological  Falciparum Malaria Protein 11 with AS01B adjuv...
# 6             Drug                                        Retapamulin
# 7            Other                                    Data collection
# 8             Drug                                       Mifepristone
# 9       Behavioral                                         Video Game
#
#                              InterventionDescription  \
# 0  The Velieve U.S. is a home use, in-vitro diagn...
# 1  Surveying Marshallese adults in the U.S. to de...
# 2  Counselors underwent training on the use of 10...
# 3  The study will use multiple primary data sourc...
# 4                                            vaccine
# 5                       malaria experimental vaccine
# 6            Prescription sales claim of retapamulin
# 7  Data collection from existing electronic healt...
# 8  All participants will receive 200 mg mifeprist...
# 9  Educational anti-tobacco video game played on ...
#
#                        InterventionArmGroupLabelList  \
# 0    {'InterventionArmGroupLabel': ['Velieve U.S.']}
# 1  {'InterventionArmGroupLabel': ['Marshallese in...
# 2    {'InterventionArmGroupLabel': ['Intervention']}
# 3  {'InterventionArmGroupLabel': ['Influenza Grou...
# 4  {'InterventionArmGroupLabel': ['10µg dose FMP0...
# 5  {'InterventionArmGroupLabel': ['10ug dose FMP0...
# 6  {'InterventionArmGroupLabel': ['19 to 65 years...
# 7     {'InterventionArmGroupLabel': ['Study Group']}
# 8  {'InterventionArmGroupLabel': ['Medical menstr...
# 9    {'InterventionArmGroupLabel': ['Intervention']}
#
#                            InterventionOtherNameList
# 0                                                NaN
# 1                                                NaN
# 2  {'InterventionOtherName': ['Improving contrace...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
df2 = pd.concat([cf, cf["C"].apply(lambda x: pd.Series(x[0]))], axis=1)
df2
# Out:
#          NCTId                                                  C  \
# 0  NCT04371159  [{'InterventionType': 'Device', 'InterventionN...
# 1  NCT04474496  [{'InterventionType': 'Other', 'InterventionNa...
# 2  NCT02801266  [{'InterventionType': 'Behavioral', 'Intervent...
# 3  NCT01599390  [{'InterventionType': 'Other', 'InterventionNa...
# 4  NCT00312702  [{'InterventionType': 'Biological', 'Intervent...
# 5  NCT00312663  [{'InterventionType': 'Biological', 'Intervent...
# 6  NCT01153880  [{'InterventionType': 'Drug', 'InterventionNam...
# 7  NCT02019732  [{'InterventionType': 'Other', 'InterventionNa...
# 8  NCT03972358  [{'InterventionType': 'Drug', 'InterventionNam...
# 9  NCT00948233  [{'InterventionType': 'Behavioral', 'Intervent...
#
#   InterventionType                                   InterventionName  \
# 0           Device                                       Velieve U.S.
# 1            Other                        Assessing impact of COVID19
# 2       Behavioral         Evidence informed birth control counseling
# 3            Other                                    Data collection
# 4       Biological  Falciparum Malaria Protein 11 with AS02A adjuvant
# 5       Biological  Falciparum Malaria Protein 11 with AS01B adjuv...
# 6             Drug                                        Retapamulin
# 7            Other                                    Data collection
# 8             Drug                                       Mifepristone
# 9       Behavioral                                         Video Game
#
#                              InterventionDescription  \
# 0  The Velieve U.S. is a home use, in-vitro diagn...
# 1  Surveying Marshallese adults in the U.S. to de...
# 2  Counselors underwent training on the use of 10...
# 3  The study will use multiple primary data sourc...
# 4                                            vaccine
# 5                       malaria experimental vaccine
# 6            Prescription sales claim of retapamulin
# 7  Data collection from existing electronic healt...
# 8  All participants will receive 200 mg mifeprist...
# 9  Educational anti-tobacco video game played on ...
#
#                        InterventionArmGroupLabelList  \
# 0    {'InterventionArmGroupLabel': ['Velieve U.S.']}
# 1  {'InterventionArmGroupLabel': ['Marshallese in...
# 2    {'InterventionArmGroupLabel': ['Intervention']}
# 3  {'InterventionArmGroupLabel': ['Influenza Grou...
# 4  {'InterventionArmGroupLabel': ['10µg dose FMP0...
# 5  {'InterventionArmGroupLabel': ['10ug dose FMP0...
# 6  {'InterventionArmGroupLabel': ['19 to 65 years...
# 7     {'InterventionArmGroupLabel': ['Study Group']}
# 8  {'InterventionArmGroupLabel': ['Medical menstr...
# 9    {'InterventionArmGroupLabel': ['Intervention']}
#
#                            InterventionOtherNameList
# 0                                                NaN
# 1                                                NaN
# 2  {'InterventionOtherName': ['Improving contrace...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %% [markdown]
# Pre process : create an index table
# 1. copy index table
# 2. add a column that has features to be need to be brokenup
# 2. sort the table so that the 0 goes to the bottom of the table
# 3. count the number of NaN
# 4. adjust the table row number as to the non NaN items
# 5. process the table
# 6. left merge the table with index table

# %%
# copy table table
# column_name = 'ProtocolSection.ArmsInterventionsModule.InterventionList.Intervention'
tb_df = index_table.copy()
tb_df['ProtocolSection.ArmsInterventionsModule.InterventionList.Intervention'] = norm_df['ProtocolSection.ArmsInterventionsModule.InterventionList.Intervention']
tb_df = tb_df.rename(columns={'ProtocolSection.ArmsInterventionsModule.InterventionList.Intervention': "C"})
tb_df = tb_df.sort_values(by=['C'])
#df.sort_values()
tb_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-4b5c8cc57d1a> in <module>
#       4 tb_df['ProtocolSection.ArmsInterventionsModule.InterventionList.Intervention'] = norm_df['ProtocolSection.ArmsInterventionsModule.InterventionList.Intervention']
#       5 tb_df = tb_df.rename(columns={'ProtocolSection.ArmsInterventionsModule.InterventionList.Intervention': "C"})
# ----> 6 tb_df = tb_df.sort_values(by=['C'])
#       7 #df.sort_values()
#       8 tb_df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4931
#    4932             indexer = nargsort(
# -> 4933                 k, kind=kind, ascending=ascending, na_position=na_position
#    4934             )
#    4935
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\sorting.py in nargsort(items, kind, ascending, na_position)
#     272         non_nans = non_nans[::-1]
#     273         non_nan_idx = non_nan_idx[::-1]
# --> 274     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     275     if not ascending:
#     276         indexer = indexer[::-1]
#
# TypeError: '<' not supported between instances of 'dict' and 'dict'

# %% [markdown]
# https://stackoverflow.com/questions/29742975/python-pandas-how-to-split-a-sorted-dictionary-in-a-column-of-a-dataframe
