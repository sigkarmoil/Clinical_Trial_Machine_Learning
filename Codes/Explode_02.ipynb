# %%
# Dependencies
import json
import os
import pandas as pd

# %%
#open json
object_path = 'renamed_all_data.json'
with open(object_path) as jsonfile:
       data_json = json.load(jsonfile)
df_from_json = pd.DataFrame(data_json)

# %%
df_from_json
# Out:
#               NCTId                           ArmGroupInterventionName  \
# 0       NCT04371159                               Device: Velieve U.S.
# 1       NCT04474496                 Other: Assessing impact of COVID19
# 2       NCT02801266  Behavioral: Evidence informed birth control co...
# 3       NCT01599390                             Other: Data collection
# 4       NCT00312702  [Biological: Falciparum Malaria Protein 11 wit...
# ...             ...                                                ...
# 138972  NCT00002678  [Drug: melphalan, Drug: prednisone, Drug: dexa...
# 138973  NCT04183179     Behavioral: Happy Family, Healthy Kids Program
# 138974  NCT03278743  [Other: Cognitive performance and cognitive de...
# 138975  NCT02740686  [Other: Sample collection, Other: Sample colle...
# 138976  NCT04403789  [Other: Exercise Time, Behavioral: Supervised ...
#
#                                   ArmGroupType BaselineMeasureDispersionType  \
# ...

# %%
def explodeTable(df_name, column_name):
    tb = df_name[['NCTId', column_name]].copy()
    tb = tb.explode(column_name)
    #create cross table
    Cross_Tb = pd.crosstab(index=tb['NCTId'], columns = tb[column_name])
    #Creating 0 and 1 matrix table
    Cross_Tb[Cross_Tb>1]=1
    Cross_Tb.reset_index()
    
    return Cross_Tb

# %%
Cross_Tb2= explodeTable(df_from_json, 'ArmGroupType')
#Cross_Tb2.to_csv('CSVTables/Cross_Tb2.csv')
Cross_Tb2
# Out:
# ArmGroupType  0  Active Comparator  Experimental  No Intervention  Other  \
# NCTId
# NCT00000102   1                  0             0                0      0
# NCT00000104   1                  0             0                0      0
# NCT00000105   1                  0             0                0      0
# NCT00000106   1                  0             0                0      0
# NCT00000107   1                  0             0                0      0
# ...          ..                ...           ...              ...    ...
# NCT04609995   0                  1             0                1      0
# NCT04610164   0                  0             1                1      0
# NCT04610515   1                  0             0                0      0
# NCT04610658   0                  0             1                0      0
# NCT04610671   0                  0             1                0      0
#
# ArmGroupType  Placebo Comparator  Sham Comparator
# NCTId
# ...

# %%
Cross_Tb3= explodeTable(df_from_json, 'BaselineMeasureDispersionType')
#Cross_Tb3.to_csv('CSVTables/Cross_Tb3.csv')
Cross_Tb3
# Out:
# BaselineMeasureDispersionType  0  Full Range  Inter-Quartile Range  \
# NCTId
# NCT00000102                    1           0                     0
# NCT00000104                    1           0                     0
# NCT00000105                    1           0                     0
# NCT00000106                    1           0                     0
# NCT00000107                    1           0                     0
# ...                           ..         ...                   ...
# NCT04609995                    1           0                     0
# NCT04610164                    1           0                     0
# NCT04610515                    1           0                     0
# NCT04610658                    1           0                     0
# NCT04610671                    1           0                     0
#
# BaselineMeasureDispersionType  Standard Deviation
# NCTId
# NCT00000102                                     0
# ...

# %%
Cross_Tb4= explodeTable(df_from_json, 'BaselineMeasureParamType')
Cross_Tb4.to_csv('CSVTables/Cross_Tb4.csv')
Cross_Tb4
# Out:
# BaselineMeasureParamType  0  Count of Participants  Count of Units  \
# NCTId
# NCT00000102               1                      0               0
# NCT00000104               1                      0               0
# NCT00000105               1                      0               0
# NCT00000106               1                      0               0
# NCT00000107               1                      0               0
# ...                      ..                    ...             ...
# NCT04609995               1                      0               0
# NCT04610164               1                      0               0
# NCT04610515               1                      0               0
# NCT04610658               1                      0               0
# NCT04610671               1                      0               0
#
# BaselineMeasureParamType  Geometric Least Squares Mean  Geometric Mean  \
# NCTId
# NCT00000102                                          0               0
# ...

# %%
Cross_Tb5= explodeTable(df_from_json, 'CollaboratorClass')
Cross_Tb5.to_csv('CSVTables/Cross_Tb5.csv')
Cross_Tb5
# Out:
# CollaboratorClass  0  AMBIG  FED  INDIV  INDUSTRY  NETWORK  NIH  OTHER  \
# NCTId
# NCT00000102        1      0    0      0         0        0    0      0
# NCT00000104        0      0    1      0         0        0    0      0
# NCT00000105        1      0    0      0         0        0    0      0
# NCT00000106        1      0    0      0         0        0    0      0
# NCT00000107        1      0    0      0         0        0    0      0
# ...               ..    ...  ...    ...       ...      ...  ...    ...
# NCT04609995        1      0    0      0         0        0    0      0
# NCT04610164        1      0    0      0         0        0    0      0
# NCT04610515        0      0    0      0         0        0    0      1
# NCT04610658        0      0    0      0         1        0    0      0
# NCT04610671        0      0    0      0         0        0    0      0
#
# CollaboratorClass  OTHER_GOV  UNKNOWN
# NCTId
# NCT00000102                0        0
# ...

# %%
Cross_Tb7= explodeTable(df_from_json, 'ConditionBrowseBranchAbbrev')
Cross_Tb7.to_csv('CSVTables/Cross_Tb7.csv')
Cross_Tb7
# Out:
# ConditionBrowseBranchAbbrev  0  All  BC01  BC02  BC03  BC04  BC05  BC06  BC07  \
# NCTId
# NCT00000102                  0    1     0     0     0     0     0     0     0
# NCT00000104                  0    1     0     0     0     0     0     0     0
# NCT00000105                  0    1     1     0     0     0     0     0     0
# NCT00000106                  0    1     0     0     0     0     1     0     0
# NCT00000107                  0    1     0     0     0     0     0     0     0
# ...                         ..  ...   ...   ...   ...   ...   ...   ...   ...
# NCT04609995                  0    1     0     1     0     0     0     0     0
# NCT04610164                  0    1     0     0     0     0     0     0     0
# NCT04610515                  0    1     1     1     0     0     0     0     0
# NCT04610658                  0    1     0     0     0     1     0     0     0
# NCT04610671                  0    1     0     0     0     1     0     0     0
#
# ...

# %%
Cross_Tb10= explodeTable(df_from_json, 'DesignAllocation')
Cross_Tb10.to_csv('CSVTables/Cross_Tb10.csv')
Cross_Tb10
# Out:
# DesignAllocation  0  N/A  Non-Randomized  Randomized
# NCTId
# NCT00000102       1    0               0           0
# NCT00000104       1    0               0           0
# NCT00000105       1    0               0           0
# NCT00000106       0    0               0           1
# NCT00000107       1    0               0           0
# ...              ..  ...             ...         ...
# NCT04609995       0    0               0           1
# NCT04610164       0    0               0           1
# NCT04610515       1    0               0           0
# NCT04610658       0    0               1           0
# NCT04610671       0    1               0           0
#
# [138977 rows x 4 columns]

# %%
Cross_Tb11= explodeTable(df_from_json, 'DesignMasking')
Cross_Tb11.to_csv('CSVTables/Cross_Tb11.csv')
Cross_Tb11
# Out:
# DesignMasking  0  Double  None (Open Label)  Quadruple  Single  Triple
# NCTId
# NCT00000102    0       1                  0          0       0       0
# NCT00000104    1       0                  0          0       0       0
# NCT00000105    1       0                  0          0       0       0
# NCT00000106    1       0                  0          0       0       0
# NCT00000107    1       0                  0          0       0       0
# ...           ..     ...                ...        ...     ...     ...
# NCT04609995    0       0                  1          0       0       0
# NCT04610164    0       1                  0          0       0       0
# NCT04610515    1       0                  0          0       0       0
# NCT04610658    0       0                  1          0       0       0
# NCT04610671    0       0                  1          0       0       0
#
# [138977 rows x 6 columns]

# %%
Cross_Tb12= explodeTable(df_from_json, 'DesignPrimaryPurpose')
Cross_Tb12.to_csv('CSVTables/Cross_Tb12.csv')
Cross_Tb12
# Out:
# DesignPrimaryPurpose  0  Basic Science  Device Feasibility  Diagnostic  \
# NCTId
# NCT00000102           0              0                   0           0
# NCT00000104           1              0                   0           0
# NCT00000105           1              0                   0           0
# NCT00000106           0              0                   0           0
# NCT00000107           1              0                   0           0
# ...                  ..            ...                 ...         ...
# NCT04609995           0              0                   0           0
# NCT04610164           0              0                   0           0
# NCT04610515           1              0                   0           0
# NCT04610658           0              0                   0           0
# NCT04610671           0              0                   0           0
#
# DesignPrimaryPurpose  Educational/Counseling/Training  \
# NCTId
# ...

# %%
Cross_Tb13= explodeTable(df_from_json, 'DesignTimePerspective')
Cross_Tb13.to_csv('CSVTables/Cross_Tb13.csv')
Cross_Tb13
# Out:
# DesignTimePerspective  0  Cross-Sectional  Other  Prospective  Retrospective
# NCTId
# NCT00000102            1                0      0            0              0
# NCT00000104            0                0      1            0              0
# NCT00000105            0                0      0            1              0
# NCT00000106            1                0      0            0              0
# NCT00000107            1                0      0            0              0
# ...                   ..              ...    ...          ...            ...
# NCT04609995            1                0      0            0              0
# NCT04610164            1                0      0            0              0
# NCT04610515            0                0      0            1              0
# NCT04610658            1                0      0            0              0
# NCT04610671            1                0      0            0              0
#
# [138977 rows x 5 columns]

# %%
Cross_Tb15= explodeTable(df_from_json, 'HealthyVolunteers')
Cross_Tb15.to_csv('CSVTables/Cross_Tb15.csv')
Cross_Tb15
# Out:
# HealthyVolunteers  0  Accepts Healthy Volunteers  No
# NCTId
# NCT00000102        0                           0   1
# NCT00000104        0                           1   0
# NCT00000105        0                           1   0
# NCT00000106        0                           0   1
# NCT00000107        0                           1   0
# ...               ..                         ...  ..
# NCT04609995        0                           1   0
# NCT04610164        0                           1   0
# NCT04610515        1                           0   0
# NCT04610658        0                           0   1
# NCT04610671        0                           0   1
#
# [138977 rows x 3 columns]

# %%
Cross_Tb17= explodeTable(df_from_json, 'InterventionBrowseBranchAbbrev')
Cross_Tb17.to_csv('CSVTables/Cross_Tb17.csv')
Cross_Tb17
# Out:
# InterventionBrowseBranchAbbrev  0  AA  AAll  ANeo  ARhu  AdjAn  AlcDet  All  \
# NCTId
# NCT00000102                     0   0     0     0     0      0       0    1
# NCT00000104                     1   0     0     0     0      0       0    0
# NCT00000105                     0   0     0     0     0      0       0    1
# NCT00000106                     1   0     0     0     0      0       0    0
# NCT00000107                     1   0     0     0     0      0       0    0
# ...                            ..  ..   ...   ...   ...    ...     ...  ...
# NCT04609995                     1   0     0     0     0      0       0    0
# NCT04610164                     0   0     0     0     0      0       0    1
# NCT04610515                     1   0     0     0     0      0       0    0
# NCT04610658                     0   0     0     1     0      0       0    1
# NCT04610671                     0   0     0     1     0      0       0    1
#
# ...

# %%
Cross_Tb20= explodeTable(df_from_json, 'InterventionType')
Cross_Tb20.to_csv('CSVTables/Cross_Tb20.csv')
Cross_Tb20
# Out:
# InterventionType  0  Behavioral  Biological  Combination Product  Device  \
# NCTId
# NCT00000102       0           0           0                    0       0
# NCT00000104       0           0           0                    0       0
# NCT00000105       0           0           1                    0       0
# NCT00000106       0           0           0                    0       1
# NCT00000107       1           0           0                    0       0
# ...              ..         ...         ...                  ...     ...
# NCT04609995       0           1           0                    0       0
# NCT04610164       0           0           0                    0       0
# NCT04610515       1           0           0                    0       0
# NCT04610658       0           0           0                    0       0
# NCT04610671       0           0           0                    0       0
#
# InterventionType  Diagnostic Test  Dietary Supplement  Drug  Genetic  Other  \
# ...

# %%
Cross_Tb21= explodeTable(df_from_json, 'IsFDARegulatedDevice')
Cross_Tb21.to_csv('CSVTables/Cross_Tb21.csv')
Cross_Tb21
# Out:
# IsFDARegulatedDevice  0  No  Yes
# NCTId
# NCT00000102           1   0    0
# NCT00000104           1   0    0
# NCT00000105           1   0    0
# NCT00000106           1   0    0
# NCT00000107           1   0    0
# ...                  ..  ..  ...
# NCT04609995           0   1    0
# NCT04610164           0   1    0
# NCT04610515           0   1    0
# NCT04610658           0   1    0
# NCT04610671           0   1    0
#
# [138977 rows x 3 columns]

# %%
Cross_Tb22= explodeTable(df_from_json, 'IsFDARegulatedDrug')
Cross_Tb22.to_csv('CSVTables/Cross_Tb22.csv')
Cross_Tb22
# Out:
# IsFDARegulatedDrug  0  No  Yes
# NCTId
# NCT00000102         1   0    0
# NCT00000104         1   0    0
# NCT00000105         1   0    0
# NCT00000106         1   0    0
# NCT00000107         1   0    0
# ...                ..  ..  ...
# NCT04609995         0   1    0
# NCT04610164         0   0    1
# NCT04610515         0   1    0
# NCT04610658         0   0    1
# NCT04610671         0   0    1
#
# [138977 rows x 3 columns]

# %%
Cross_Tb23= explodeTable(df_from_json, 'LeadSponsorClass')
Cross_Tb23.to_csv('CSVTables/Cross_Tb23.csv')
Cross_Tb23
# Out:
# LeadSponsorClass  0  FED  INDIV  INDUSTRY  NETWORK  NIH  OTHER  OTHER_GOV  \
# NCTId
# NCT00000102       0    0      0         0        0    1      0          0
# NCT00000104       0    0      0         0        0    1      0          0
# NCT00000105       0    0      0         0        0    0      1          0
# NCT00000106       0    0      0         0        0    1      0          0
# NCT00000107       0    0      0         0        0    1      0          0
# ...              ..  ...    ...       ...      ...  ...    ...        ...
# NCT04609995       0    0      0         0        0    0      1          0
# NCT04610164       0    0      0         0        0    0      1          0
# NCT04610515       0    0      0         0        0    0      1          0
# NCT04610658       0    0      0         0        0    0      1          0
# NCT04610671       0    0      0         0        0    0      1          0
#
# LeadSponsorClass  UNKNOWN
# NCTId
# NCT00000102             0
# ...

# %%
Cross_Tb25= explodeTable(df_from_json, 'PatientRegistry')
Cross_Tb25.to_csv('CSVTables/Cross_Tb25.csv')
Cross_Tb25
# Out:
# PatientRegistry  0  No  Yes
# NCTId
# NCT00000102      1   0    0
# NCT00000104      1   0    0
# NCT00000105      1   0    0
# NCT00000106      1   0    0
# NCT00000107      1   0    0
# ...             ..  ..  ...
# NCT04609995      1   0    0
# NCT04610164      1   0    0
# NCT04610515      0   0    1
# NCT04610658      1   0    0
# NCT04610671      1   0    0
#
# [138977 rows x 3 columns]

# %%
Cross_Tb27= explodeTable(df_from_json, 'SamplingMethod')
Cross_Tb27.to_csv('CSVTables/Cross_Tb27.csv')
Cross_Tb27
# Out:
# SamplingMethod  0  Non-Probability Sample  Probability Sample
# NCTId
# NCT00000102     1                       0                   0
# NCT00000104     1                       0                   0
# NCT00000105     0                       0                   1
# NCT00000106     1                       0                   0
# NCT00000107     1                       0                   0
# ...            ..                     ...                 ...
# NCT04609995     1                       0                   0
# NCT04610164     1                       0                   0
# NCT04610515     0                       1                   0
# NCT04610658     1                       0                   0
# NCT04610671     1                       0                   0
#
# [138977 rows x 3 columns]

# %%
Cross_Tb28= explodeTable(df_from_json, 'StdAge')
Cross_Tb28.to_csv('CSVTables/Cross_Tb28.csv')
Cross_Tb28
# Out:
# StdAge       0  Adult  Child  Older Adult
# NCTId
# NCT00000102  0      1      1            0
# NCT00000104  0      1      1            1
# NCT00000105  0      1      0            1
# NCT00000106  0      1      0            1
# NCT00000107  0      1      1            0
# ...         ..    ...    ...          ...
# NCT04609995  0      1      0            0
# NCT04610164  0      1      0            1
# NCT04610515  0      1      0            1
# NCT04610658  0      1      0            1
# NCT04610671  0      1      0            1
#
# [138977 rows x 4 columns]

# %%
Cross_Tb29= explodeTable(df_from_json, 'StudyType')
Cross_Tb29.to_csv('CSVTables/Cross_Tb29.csv')
Cross_Tb29
# Out:
# StudyType    0  Expanded Access  Interventional  Observational
# NCTId
# NCT00000102  0                0               1              0
# NCT00000104  0                0               0              1
# NCT00000105  0                0               0              1
# NCT00000106  0                0               1              0
# NCT00000107  0                0               0              1
# ...         ..              ...             ...            ...
# NCT04609995  0                0               1              0
# NCT04610164  0                0               1              0
# NCT04610515  0                0               0              1
# NCT04610658  0                0               1              0
# NCT04610671  0                0               1              0
#
# [138977 rows x 4 columns]
