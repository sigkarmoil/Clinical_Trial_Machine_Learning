# %%
import json

# %%
object_path = '../Resources/all_data.json'

with open(object_path) as jsonfile:
       data_json = json.load(jsonfile)

# %%
data_json
# Out:
# {'NCTId': ['NCT04371159',
#   'NCT04474496',
#   'NCT02801266',
#   'NCT01599390',
#   'NCT00312702',
#   'NCT00312663',
#   'NCT01153880',
#   'NCT02019732',
#   'NCT03972358',
#   'NCT00948233',
#   'NCT00026728',
#   'NCT01211990',
#   'NCT02663219',
#   'NCT00121108',
#   'NCT01861210',
#   'NCT02911155',
#   'NCT00724867',
#   'NCT03973905',
#   'NCT00340457',
#   'NCT02429284',
#   'NCT02889263',
#   'NCT03995745',
#   'NCT00928694',
#   'NCT02153996',
#   'NCT00413673',
#   'NCT03867409',
#   'NCT04004260',
#   'NCT04205877',
#   'NCT01262079',
#   'NCT00646438',
#   'NCT00341588',
#   'NCT04562636',
#   'NCT03924505',
#   'NCT02334462',
#   'NCT03311295',
#   'NCT03242278',
#   'NCT03683134',
#   'NCT04047316',
#   'NCT03952364',
#   'NCT04021030',
#   'NCT02959827',
#   'NCT02395536',
#   'NCT03628235',
#   'NCT02787538',
#   'NCT01290393',
#   'NCT04263311',
#   'NCT00875641',
#   'NCT03199846',
#   'NCT04587245',
#   'NCT02773979',
#   'NCT03274726',
#   'NCT01283828',
# ...

# %%
data_json["ConditionAncestorId "]
# Out:
# [['D000007239', 'D000014570'],
#  0,
#  0,
#  ['D000009976', 'D000012327', 'D000014777', 'D000012141', 'D000012140'],
#  ['D000011528', 'D000010272'],
#  ['D000011528', 'D000010272'],
#  ['D000007239',
#   'D000013492',
#   'D000003240',
#   'D000007249',
#   'D000010335',
#   'D000012871'],
#  ['D000009976', 'D000012327', 'D000014777', 'D000012141', 'D000012140'],
#  0,
#  0,
#  ['D000018204',
#   'D000009370',
#   'D000009369',
#   'D000004266',
#   'D000014777',
#   'D000009383'],
#  0,
#  0,
#  0,
#  0,
#  ['D000004701',
#   'D000009371',
#   'D000009369',
#   'D000006258',
#   'D000004700',
#   'D000013959',
#   'D000016543',
#   'D000009423',
#   'D000001927',
#   'D000002493',
#   'D000009422',
#   'D000010335'],
#  ['D000003240', 'D000001327', 'D000007154'],
#  ['D000012140',
#   'D000001885',
#   'D000016905',
#   'D000001424',
#   'D000012141',
#   'D000007239'],
#  ['D000002277',
#   'D000009375',
#   'D000009370',
#   'D000009369',
#   'D000000230',
#   'D000014571',
# ...

# %%
data_json["ConditionAncestorId"] = data_json.pop("ConditionAncestorId ")

# %%
data_json["SamplingMethod"] = data_json.pop("SamplingMethod ")

# %%
with open('../Resources/renamed_all_data.json', 'w') as json_file:
    json.dump(data_json, json_file)

# %%
a_dict = {"a": 1, "B": 2, "C": 3}

new_key = "A"
old_key = "a"
a_dict[new_key] = a_dict.pop(old_key)
