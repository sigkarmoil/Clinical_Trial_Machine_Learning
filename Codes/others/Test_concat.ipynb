# %%
import requests
import pprint
import json
import time
import pandas as pd

# %%
df1 = pd.read_csv("json2/field_usa0_part_1.csv")
df2 = pd.read_csv("json2/field_usa1_part_1.csv")

# %%
pd.concat([df1,df2])
# Out:
#      Unnamed: 0  Rank            NCTId AgreementOtherDetails  \
# 0             0     1  ['NCT04371159']                    []
# 1             0     2  ['NCT04474496']                    []
# 2             0     3  ['NCT02801266']                    []
# 3             0     4  ['NCT01599390']                    []
# 4             0     5  ['NCT00312702']                    []
# ..          ...   ...              ...                   ...
# 995           0  1996  ['NCT03311646']                    []
# 996           0  1997  ['NCT03865303']                    []
# 997           0  1998  ['NCT04461184']                    []
# 998           0  1999  ['NCT03711630']                    []
# 999           0  2000  ['NCT02408029']                    []
#
#     AgreementPISponsorEmployee AgreementRestrictionType  \
# 0                           []                       []
# 1                           []                       []
# 2                           []                       []
# ...
